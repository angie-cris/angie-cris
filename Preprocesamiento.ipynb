# %% [markdown]
# <a href="https://colab.research.google.com/github/angie-cris/angie-cris/blob/main/Preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocesamiento rápido de bases de datos estatales sobre producción agropecuaria como insumo para publicación en Probogotá Región.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('/content/Base Agropecuaria.xlsx', header=6)
df.head()
# Out:
#    Código Dane departamento Departamento  Código Dane municipio Municipio  \
# 0                         5    Antioquia                   5001  Medellín
# 1                         5    Antioquia                   5001  Medellín
# 2                         5    Antioquia                   5001  Medellín
# 3                         5    Antioquia                   5001  Medellín
# 4                         5    Antioquia                   5001  Medellín
#
#        Desagregación cultivo   Cultivo Ciclo del cultivo Grupo cultivo  \
# 0  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 1  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 2  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 3  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 4  Aguacate demás variedades  Aguacate        Permanente      Frutales
#
#          Subgrupo   Año Periodo  Área sembrada (ha)  Área cosechada (ha)  \
# ...

# %%
df['Grupo cultivo'].unique()
# Out:
# array(['Frutales', 'Hortalizas', 'Leguminosas',
#        'Cultivos tropicales tradicionales', 'Raíces y tubérculos',
#        'Cultivos para condimentos, bebidas medicinales y aromáticas',
#        'Cereales', 'Oleaginosas'], dtype=object)

# %%
df_filtrado = df[(df['Año'].isin([2023])) & (df['Periodo'].isin(["2023"]))]
df_totalizado = df_filtrado.groupby(['Código Dane municipio','Municipio', 'Grupo cultivo'])['Producción (t)'].sum().reset_index()
df_totalizado['Grupo cultivo'].unique()
df_mayor_frutas = df_totalizado[df_totalizado['Grupo cultivo'] == "Frutales"]
df_mayor_frutas = df_mayor_frutas[df_mayor_frutas['Producción (t)']>4000]
df_mayor_frutas
# Out:
#       Código Dane municipio              Municipio Grupo cultivo  \
# 3                      5002              Abejorral      Frutales
# 14                     5034                  Andes      Frutales
# 25                     5044                   Anzá      Frutales
# 27                     5045               Apartadó      Frutales
# 29                     5051              Arboletes      Frutales
# ...                     ...                    ...           ...
# 2227                  95001  San José del Guaviare      Frutales
# 2229                  95015                Calamar      Frutales
# 2231                  95025             El Retorno      Frutales
# 2241                  99001         Puerto Carreño      Frutales
# 2250                  99773               Cumaribo      Frutales
#
#       Producción (t)
# 3          30142.250
# 14          8427.880
# 25          8962.600
# 27        441714.000
# 29         30145.300
# ...              ...
# 2227       41798.000
# ...

# %%
df_mayor_4000['Código Dane municipio'] = df_mayor_4000['Código Dane municipio'].astype(str).str.zfill(4)
# Out:
# <ipython-input-6-72c5b14c2383>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mayor_4000['Código Dane municipio'] = df_mayor_4000['Código Dane municipio'].astype(str).str.zfill(4)

# %%
df_mayor_frutas.to_csv("frutalesMunicipios.csv", index=False, encoding="utf-8")
